# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["main"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | shache
# Processing Record 5 of Set 1 | mackay
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | werda
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | shingu
# Processing Record 10 of Set 1 | tecoanapa
# Processing Record 11 of Set 1 | berlevag
# Processing Record 12 of Set 1 | nome
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | kongoussi
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | nyeri
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | padang
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 1 | riyadh
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | oudtshoorn
# Processing Record 34 of Set 1 | kasane
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | kirakira
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | itatiaia
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | termoli
# Processing Record 3 of Set 2 | arcachon
# Processing Record 4 of Set 2 | beringovskiy
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | dodge city
# Processing Record 7 of Set 2 | jertih
# Processing Record 8 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | oranjestad
# Processing Record 11 of Set 2 | roald
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | kargopol
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | sinjar
# Processing Record 18 of Set 2 | sailana
# Processing Record 19 of Set 2 | caiaponia
# Processing Record 20 of Set 2 | tigre
# Processing Record 21 of Set 2 | canasgordas
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | manokwari
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | maarianhamina
# Processing Record 29 of Set 2 | baruun-urt
# Processing Record 30 of Set 2 | tigil
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | thanh hoa
# Processing Record 33 of Set 2 | nisia floresta
# Processing Record 34 of Set 2 | birjand
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | egvekinot
# Processing Record 38 of Set 2 | najran
# Processing Record 39 of Set 2 | rabo de peixe
# Processing Record 40 of Set 2 | atherton
# Processing Record 41 of Set 2 | zhezkazgan
# Processing Record 42 of Set 2 | zabol
# Processing Record 43 of Set 2 | gombong
# Processing Record 44 of Set 2 | galeana
# Processing Record 45 of Set 2 | iqaluit
# Processing Record 46 of Set 2 | flin flon
# Processing Record 47 of Set 2 | morant bay
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | tandil
# Processing Record 50 of Set 2 | preobrazheniye
# Processing Record 1 of Set 3 | kloulklubed
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | leh
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | lima
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | atar
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | vostok
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | otofuke
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | mackenzie
# Processing Record 19 of Set 3 | pathein
# Processing Record 20 of Set 3 | sungaipenuh
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | campobasso
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | mount isa
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | hay river
# Processing Record 28 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 3 | sistranda
# Processing Record 30 of Set 3 | gewane
# Processing Record 31 of Set 3 | makasar
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | koumac
# Processing Record 34 of Set 3 | vao
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | agrestina
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | atuona
# Processing Record 39 of Set 3 | bongandanga
# Processing Record 40 of Set 3 | xichang
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | zlitan
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | teguise
# Processing Record 49 of Set 3 | baherden
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | nanortalik
# Processing Record 2 of Set 4 | luganville
# Processing Record 3 of Set 4 | komsomolskiy
# Processing Record 4 of Set 4 | deputatskiy
# Processing Record 5 of Set 4 | opuwo
# Processing Record 6 of Set 4 | hualmay
# Processing Record 7 of Set 4 | wawa
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | nyurba
# Processing Record 12 of Set 4 | rio grande
# Processing Record 13 of Set 4 | jacareacanga
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | coracao de jesus
# Processing Record 17 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 4 | parrita
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | shitanjing
# Processing Record 21 of Set 4 | oktyabrskoye
# Processing Record 22 of Set 4 | potam
# Processing Record 23 of Set 4 | jamestown
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | pimentel
# Processing Record 26 of Set 4 | suez
# Processing Record 27 of Set 4 | waipawa
# Processing Record 28 of Set 4 | kameshkovo
# Processing Record 29 of Set 4 | shimoda
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | saintes
# Processing Record 34 of Set 4 | aksu
# Processing Record 35 of Set 4 | lanquin
# Processing Record 36 of Set 4 | dmitriyevskoye
# Processing Record 37 of Set 4 | hilo
# Processing Record 38 of Set 4 | tautira
# Processing Record 39 of Set 4 | butaritari
# Processing Record 40 of Set 4 | srednekolymsk
# Processing Record 41 of Set 4 | sharjah
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | abalak
# Processing Record 44 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 4 | awjilah
# Processing Record 46 of Set 4 | adrar
# Processing Record 47 of Set 4 | omsukchan
# Processing Record 48 of Set 4 | bowen
# Processing Record 49 of Set 4 | owando
# Processing Record 50 of Set 4 | broome
# Processing Record 1 of Set 5 | semme
# Processing Record 2 of Set 5 | domoni
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | maragogi
# Processing Record 5 of Set 5 | saint-denis
# Processing Record 6 of Set 5 | puerto ayora
# Processing Record 7 of Set 5 | santa isabel do rio negro
# Processing Record 8 of Set 5 | nizwa
# Processing Record 9 of Set 5 | catamarca
# Processing Record 10 of Set 5 | aripuana
# Processing Record 11 of Set 5 | ankang
# Processing Record 12 of Set 5 | boa vista
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | chernyshevskiy
# Processing Record 15 of Set 5 | baykit
# Processing Record 16 of Set 5 | el jicaro
# Processing Record 17 of Set 5 | thinadhoo
# Processing Record 18 of Set 5 | liminangcong
# City not found. Skipping...
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | fayaoue
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | henties bay
# Processing Record 23 of Set 5 | bengkulu
# Processing Record 24 of Set 5 | constantine
# Processing Record 25 of Set 5 | colares
# Processing Record 26 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 5 | fairbanks
# Processing Record 28 of Set 5 | puerto lempira
# Processing Record 29 of Set 5 | tanhacu
# Processing Record 30 of Set 5 | languyan
# Processing Record 31 of Set 5 | vila
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | wajima
# Processing Record 34 of Set 5 | ambilobe
# Processing Record 35 of Set 5 | narasimharajapura
# Processing Record 36 of Set 5 | half moon bay
# Processing Record 37 of Set 5 | clyde river
# Processing Record 38 of Set 5 | mukhen
# Processing Record 39 of Set 5 | olafsvik
# Processing Record 40 of Set 5 | prachin buri
# Processing Record 41 of Set 5 | svetlogorsk
# Processing Record 42 of Set 5 | linden
# Processing Record 43 of Set 5 | saint-georges
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | nedjo
# Processing Record 46 of Set 5 | shelopugino
# Processing Record 47 of Set 5 | meulaboh
# Processing Record 48 of Set 5 | turukhansk
# Processing Record 49 of Set 5 | carauari
# Processing Record 50 of Set 5 | zyryanka
# Processing Record 1 of Set 6 | palmares do sul
# Processing Record 2 of Set 6 | port macquarie
# Processing Record 3 of Set 6 | sassandra
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | nizhniy bestyakh
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | lata
# Processing Record 12 of Set 6 | hoquiam
# Processing Record 13 of Set 6 | prosperous
# Processing Record 14 of Set 6 | bam
# Processing Record 15 of Set 6 | pundaguitan
# Processing Record 16 of Set 6 | isangel
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | namatanai
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | hasaki
# Processing Record 21 of Set 6 | celestun
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | tulu bolo
# Processing Record 25 of Set 6 | kendari
# Processing Record 26 of Set 6 | kichera
# Processing Record 27 of Set 6 | saint-paul
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | tura
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | lalas
# Processing Record 33 of Set 6 | port hedland
# Processing Record 34 of Set 6 | samarai
# Processing Record 35 of Set 6 | yara
# Processing Record 36 of Set 6 | orchard homes
# Processing Record 37 of Set 6 | la ronge
# Processing Record 38 of Set 6 | roebourne
# Processing Record 39 of Set 6 | benghazi
# Processing Record 40 of Set 6 | fort nelson
# Processing Record 41 of Set 6 | rincon
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | victoria point
# Processing Record 44 of Set 6 | menongue
# Processing Record 45 of Set 6 | coruripe
# Processing Record 46 of Set 6 | caravelas
# Processing Record 47 of Set 6 | san cristobal
# Processing Record 48 of Set 6 | sobolevo
# Processing Record 49 of Set 6 | tabou
# Processing Record 50 of Set 6 | belmonte
# Processing Record 1 of Set 7 | dawson
# Processing Record 2 of Set 7 | davidson
# Processing Record 3 of Set 7 | sterling
# Processing Record 4 of Set 7 | kaeo
# Processing Record 5 of Set 7 | nicoya
# Processing Record 6 of Set 7 | davis
# Processing Record 7 of Set 7 | mizpe ramon
# City not found. Skipping...
# Processing Record 8 of Set 7 | burnie
# Processing Record 9 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 7 | ulaangom
# Processing Record 11 of Set 7 | xushan
# Processing Record 12 of Set 7 | bogor
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | chernaya kholunitsa
# Processing Record 16 of Set 7 | kavaratti
# Processing Record 17 of Set 7 | aswan
# Processing Record 18 of Set 7 | lazaro cardenas
# Processing Record 19 of Set 7 | keetmanshoop
# Processing Record 20 of Set 7 | thompson
# Processing Record 21 of Set 7 | mamakan
# Processing Record 22 of Set 7 | chaman
# Processing Record 23 of Set 7 | tazovskiy
# Processing Record 24 of Set 7 | acapulco
# Processing Record 25 of Set 7 | fort saint james
# Processing Record 26 of Set 7 | ewa beach
# Processing Record 27 of Set 7 | marsa matruh
# Processing Record 28 of Set 7 | litovko
# Processing Record 29 of Set 7 | ambulu
# Processing Record 30 of Set 7 | sabang
# Processing Record 31 of Set 7 | disna
# Processing Record 32 of Set 7 | chapais
# Processing Record 33 of Set 7 | carroll
# Processing Record 34 of Set 7 | puksoozero
# Processing Record 35 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | beloha
# Processing Record 38 of Set 7 | colomi
# Processing Record 39 of Set 7 | lavrentiya
# Processing Record 40 of Set 7 | predivinsk
# Processing Record 41 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 42 of Set 7 | harer
# Processing Record 43 of Set 7 | fountain
# Processing Record 44 of Set 7 | muros
# Processing Record 45 of Set 7 | maceio
# Processing Record 46 of Set 7 | wewak
# Processing Record 47 of Set 7 | sembe
# Processing Record 48 of Set 7 | puerto el triunfo
# Processing Record 49 of Set 7 | anadyr
# Processing Record 50 of Set 7 | nuuk
# Processing Record 1 of Set 8 | wanning
# Processing Record 2 of Set 8 | cayenne
# Processing Record 3 of Set 8 | veraval
# Processing Record 4 of Set 8 | huilong
# Processing Record 5 of Set 8 | kuryk
# Processing Record 6 of Set 8 | kaitangata
# Processing Record 7 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 8 | kalianget
# Processing Record 9 of Set 8 | suchiapa
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | mogochin
# City not found. Skipping...
# Processing Record 12 of Set 8 | chumikan
# Processing Record 13 of Set 8 | khandbari
# Processing Record 14 of Set 8 | lermontovka
# Processing Record 15 of Set 8 | lorengau
# Processing Record 16 of Set 8 | narsingdi
# Processing Record 17 of Set 8 | la palma
# Processing Record 18 of Set 8 | lasa
# Processing Record 19 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 8 | middle island
# Processing Record 21 of Set 8 | srandakan
# Processing Record 22 of Set 8 | mehamn
# Processing Record 23 of Set 8 | ous
# Processing Record 24 of Set 8 | velingara
# Processing Record 25 of Set 8 | tuatapere
# Processing Record 26 of Set 8 | katsuura
# Processing Record 27 of Set 8 | dicamay
# Processing Record 28 of Set 8 | sibenik
# Processing Record 29 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | homocea
# Processing Record 32 of Set 8 | santa maria
# Processing Record 33 of Set 8 | dalby
# Processing Record 34 of Set 8 | morlaix
# Processing Record 35 of Set 8 | maldonado
# Processing Record 36 of Set 8 | zhigansk
# Processing Record 37 of Set 8 | burgthann
# Processing Record 38 of Set 8 | cuitareo
# Processing Record 39 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 8 | arica
# Processing Record 41 of Set 8 | talara
# Processing Record 42 of Set 8 | saint-augustin
# Processing Record 43 of Set 8 | grafton
# Processing Record 44 of Set 8 | sawtell
# Processing Record 45 of Set 8 | victoriaville
# Processing Record 46 of Set 8 | kahta
# Processing Record 47 of Set 8 | arlit
# Processing Record 48 of Set 8 | oksfjord
# Processing Record 49 of Set 8 | vardo
# Processing Record 50 of Set 8 | grand-santi
# Processing Record 1 of Set 9 | lowestoft
# Processing Record 2 of Set 9 | honiara
# Processing Record 3 of Set 9 | kangaatsiaq
# Processing Record 4 of Set 9 | burns lake
# Processing Record 5 of Set 9 | barguzin
# Processing Record 6 of Set 9 | darhan
# Processing Record 7 of Set 9 | murgab
# Processing Record 8 of Set 9 | xacmaz
# Processing Record 9 of Set 9 | kluczbork
# Processing Record 10 of Set 9 | ponta delgada
# Processing Record 11 of Set 9 | aketi
# Processing Record 12 of Set 9 | ellisras
# Processing Record 13 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | muswellbrook
# Processing Record 16 of Set 9 | douentza
# Processing Record 17 of Set 9 | banda aceh
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | ilorin
# Processing Record 20 of Set 9 | longyearbyen
# Processing Record 21 of Set 9 | sukumo
# Processing Record 22 of Set 9 | poronaysk
# Processing Record 23 of Set 9 | cumra
# Processing Record 24 of Set 9 | renqiu
# Processing Record 25 of Set 9 | norman wells
# Processing Record 26 of Set 9 | pokhara
# Processing Record 27 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 9 | aksarayskiy
# Processing Record 29 of Set 9 | carutapera
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | houma
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | marsh harbour
# Processing Record 34 of Set 9 | plettenberg bay
# Processing Record 35 of Set 9 | ambon
# Processing Record 36 of Set 9 | dzialdowo
# Processing Record 37 of Set 9 | hovd
# Processing Record 38 of Set 9 | maniitsoq
# Processing Record 39 of Set 9 | matagami
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | blythe
# Processing Record 42 of Set 9 | mitu
# Processing Record 43 of Set 9 | starokostyantyniv
# Processing Record 44 of Set 9 | mayumba
# Processing Record 45 of Set 9 | slave lake
# Processing Record 46 of Set 9 | umm kaddadah
# Processing Record 47 of Set 9 | gwanda
# Processing Record 48 of Set 9 | vigrestad
# Processing Record 49 of Set 9 | asau
# Processing Record 50 of Set 9 | batagay
# Processing Record 1 of Set 10 | ninohe
# Processing Record 2 of Set 10 | moose factory
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | torbay
# Processing Record 6 of Set 10 | noshiro
# Processing Record 7 of Set 10 | panama city
# Processing Record 8 of Set 10 | margate
# Processing Record 9 of Set 10 | tailai
# Processing Record 10 of Set 10 | honningsvag
# Processing Record 11 of Set 10 | debre birhan
# Processing Record 12 of Set 10 | coquimbo
# Processing Record 13 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | ayagoz
# Processing Record 15 of Set 10 | luleburgaz
# Processing Record 16 of Set 10 | agboville
# Processing Record 17 of Set 10 | san carlos
# Processing Record 18 of Set 10 | ulan-ude
# Processing Record 19 of Set 10 | zabid
# Processing Record 20 of Set 10 | shirvan
# Processing Record 21 of Set 10 | medzilaborce
# Processing Record 22 of Set 10 | puerto leguizamo
# Processing Record 23 of Set 10 | trinidad
# Processing Record 24 of Set 10 | kassala
# Processing Record 25 of Set 10 | goderich
# Processing Record 26 of Set 10 | lishui
# Processing Record 27 of Set 10 | horsham
# Processing Record 28 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 29 of Set 10 | saint-lo
# Processing Record 30 of Set 10 | mozarlandia
# Processing Record 31 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | estepa
# Processing Record 34 of Set 10 | trairi
# Processing Record 35 of Set 10 | bud
# Processing Record 36 of Set 10 | alto araguaia
# Processing Record 37 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 10 | bobrovka
# Processing Record 39 of Set 10 | nadvoitsy
# Processing Record 40 of Set 10 | mount pleasant
# Processing Record 41 of Set 10 | voznesenye
# Processing Record 42 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 10 | amazar
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | concordia
# Processing Record 46 of Set 10 | onverwacht
# Processing Record 47 of Set 10 | lubao
# Processing Record 48 of Set 10 | omboue
# Processing Record 49 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | paamiut
# Processing Record 3 of Set 11 | tiarei
# Processing Record 4 of Set 11 | kasongo-lunda
# Processing Record 5 of Set 11 | bryan
# Processing Record 6 of Set 11 | basco
# Processing Record 7 of Set 11 | rio verde de mato grosso
# Processing Record 8 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 11 | lindsay
# Processing Record 10 of Set 11 | road town
# Processing Record 11 of Set 11 | maltahohe
# Processing Record 12 of Set 11 | manadhoo
# Processing Record 13 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 11 | quatre cocos
# Processing Record 15 of Set 11 | kurumkan
# Processing Record 16 of Set 11 | luau
# Processing Record 17 of Set 11 | bonavista
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | buta
# Processing Record 20 of Set 11 | kenai
# Processing Record 21 of Set 11 | bandarbeyla
# Processing Record 22 of Set 11 | biak
# Processing Record 23 of Set 11 | baringo
# Processing Record 24 of Set 11 | hami
# Processing Record 25 of Set 11 | buraydah
# Processing Record 26 of Set 11 | visnes
# Processing Record 27 of Set 11 | port shepstone
# Processing Record 28 of Set 11 | vagay
# Processing Record 29 of Set 11 | sangar
# Processing Record 30 of Set 11 | mecca
# Processing Record 31 of Set 11 | nouakchott
# Processing Record 32 of Set 11 | great bend
# Processing Record 33 of Set 11 | dargaville
# Processing Record 34 of Set 11 | odienne
# Processing Record 35 of Set 11 | russellville
# Processing Record 36 of Set 11 | kiruna
# Processing Record 37 of Set 11 | verkhnevilyuysk
# Processing Record 38 of Set 11 | paka
# Processing Record 39 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 40 of Set 11 | aksum
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | sao raimundo nonato
# Processing Record 43 of Set 11 | cubuk
# Processing Record 44 of Set 11 | koraput
# Processing Record 45 of Set 11 | tupik
# Processing Record 46 of Set 11 | weinan
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | cap malheureux
# Processing Record 49 of Set 11 | paris
# Processing Record 50 of Set 11 | aykhal
# Processing Record 1 of Set 12 | anicuns
# Processing Record 2 of Set 12 | havre
# Processing Record 3 of Set 12 | santa rosa
# Processing Record 4 of Set 12 | sorong
# Processing Record 5 of Set 12 | amarante do maranhao
# Processing Record 6 of Set 12 | misratah
# Processing Record 7 of Set 12 | scottsbluff
# Processing Record 8 of Set 12 | portree
# Processing Record 9 of Set 12 | hofn
# Processing Record 10 of Set 12 | loandjili
# Processing Record 11 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 12 | usumatlan
# Processing Record 13 of Set 12 | ahuimanu
# Processing Record 14 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 12 | goba
# Processing Record 16 of Set 12 | kutum
# Processing Record 17 of Set 12 | gizo
# Processing Record 18 of Set 12 | lanxi
# Processing Record 19 of Set 12 | cururupu
# Processing Record 20 of Set 12 | satrikh
# Processing Record 21 of Set 12 | chaska
# Processing Record 22 of Set 12 | tawau
# Processing Record 23 of Set 12 | west wendover
# Processing Record 24 of Set 12 | barth
# Processing Record 25 of Set 12 | hit
# Processing Record 26 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 12 | waingapu
# Processing Record 28 of Set 12 | yangjiang
# Processing Record 29 of Set 12 | volot
# Processing Record 30 of Set 12 | tsuyama
# Processing Record 31 of Set 12 | krasnoselkup
# Processing Record 32 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 12 | ambunti
# Processing Record 34 of Set 12 | florianopolis
# Processing Record 35 of Set 12 | lysva
# Processing Record 36 of Set 12 | broken hill
# Processing Record 37 of Set 12 | esperance
# Processing Record 38 of Set 12 | kuruman
# Processing Record 39 of Set 12 | aguimes
# Processing Record 40 of Set 12 | cortez
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | xai-xai
# Processing Record 43 of Set 12 | piacenza
# Processing Record 44 of Set 12 | onega
# Processing Record 45 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 12 | byron bay
# Processing Record 47 of Set 12 | aden
# Processing Record 48 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 12 | khasan
# Processing Record 50 of Set 12 | kabare
# Processing Record 1 of Set 13 | naron
# Processing Record 2 of Set 13 | chimore
# Processing Record 3 of Set 13 | tigzirt
# Processing Record 4 of Set 13 | kursumlija
# Processing Record 5 of Set 13 | muroto
# Processing Record 6 of Set 13 | ongandjera
# Processing Record 7 of Set 13 | burgos
# Processing Record 8 of Set 13 | floresta
# Processing Record 9 of Set 13 | amahai
# Processing Record 10 of Set 13 | vlasinesti
# Processing Record 11 of Set 13 | la macarena
# Processing Record 12 of Set 13 | brooks
# Processing Record 13 of Set 13 | manaus
# Processing Record 14 of Set 13 | toccoa
# Processing Record 15 of Set 13 | dalbandin
# Processing Record 16 of Set 13 | mabaruma
# Processing Record 17 of Set 13 | erzurum
# Processing Record 18 of Set 13 | nizhniy odes
# Processing Record 19 of Set 13 | grindavik
# Processing Record 20 of Set 13 | gazojak
# Processing Record 21 of Set 13 | sambava
# Processing Record 22 of Set 13 | lewistown
# Processing Record 23 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 13 | kaseda
# Processing Record 25 of Set 13 | nueva gerona
# Processing Record 26 of Set 13 | monrovia
# Processing Record 27 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 13 | raton
# Processing Record 29 of Set 13 | kinablangan
# Processing Record 30 of Set 13 | rosetta
# Processing Record 31 of Set 13 | westlock
# Processing Record 32 of Set 13 | sudak
# Processing Record 33 of Set 13 | noumea
# Processing Record 34 of Set 13 | caucaia
# Processing Record 35 of Set 13 | havelock
# Processing Record 36 of Set 13 | zeya
# Processing Record 37 of Set 13 | bitung
# Processing Record 38 of Set 13 | gat
# Processing Record 39 of Set 13 | palasa
# Processing Record 40 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 13 | ferkessedougou
# Processing Record 42 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 43 of Set 13 | oga
# Processing Record 44 of Set 13 | podor
# Processing Record 45 of Set 13 | mount gambier
# Processing Record 46 of Set 13 | rapid valley
# Processing Record 47 of Set 13 | belawan
# Processing Record 48 of Set 13 | lewiston
# Processing Record 49 of Set 13 | makarov
# Processing Record 50 of Set 13 | thaton
# Processing Record 1 of Set 14 | navolato
# Processing Record 2 of Set 14 | pasighat
# Processing Record 3 of Set 14 | bialystok
# Processing Record 4 of Set 14 | yerbogachen
# Processing Record 5 of Set 14 | gorontalo
# Processing Record 6 of Set 14 | lagos
# Processing Record 7 of Set 14 | vestmannaeyjar
# Processing Record 8 of Set 14 | qasigiannguit
# Processing Record 9 of Set 14 | santa catarina
# Processing Record 10 of Set 14 | tutoia
# Processing Record 11 of Set 14 | portland
# Processing Record 12 of Set 14 | rio gallegos
# Processing Record 13 of Set 14 | melchor de mencos
# Processing Record 14 of Set 14 | mwanza
# Processing Record 15 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 14 | hongjiang
# Processing Record 18 of Set 14 | san ignacio
# Processing Record 19 of Set 14 | paratebueno
# Processing Record 20 of Set 14 | nador
# Processing Record 21 of Set 14 | pelotas
# Processing Record 22 of Set 14 | nova venecia
# Processing Record 23 of Set 14 | faxinal
# Processing Record 24 of Set 14 | kysyl-syr
# Processing Record 25 of Set 14 | lock haven
# Processing Record 26 of Set 14 | teya
# Processing Record 27 of Set 14 | canutama
# Processing Record 28 of Set 14 | medicine hat
# Processing Record 29 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 14 | mana
# Processing Record 31 of Set 14 | ballarat
# Processing Record 32 of Set 14 | nioro
# Processing Record 33 of Set 14 | savannah bight
# Processing Record 34 of Set 14 | benguela
# Processing Record 35 of Set 14 | bereda
# Processing Record 36 of Set 14 | ust-maya
# Processing Record 37 of Set 14 | stanovoye
# Processing Record 38 of Set 14 | lake charles
# Processing Record 39 of Set 14 | general pico
# Processing Record 40 of Set 14 | berberati
# Processing Record 41 of Set 14 | carora
# Processing Record 42 of Set 14 | sai buri
# Processing Record 43 of Set 14 | sehore
# Processing Record 44 of Set 14 | vanimo
# Processing Record 45 of Set 14 | tanete
# Processing Record 46 of Set 14 | oranjemund
# Processing Record 47 of Set 14 | vana-voidu
# City not found. Skipping...
# Processing Record 48 of Set 14 | bulawayo
# Processing Record 49 of Set 14 | soe
# Processing Record 50 of Set 14 | chechat
# Processing Record 1 of Set 15 | vuktyl
# Processing Record 2 of Set 15 | inhambane
# Processing Record 3 of Set 15 | kisangani
# Processing Record 4 of Set 15 | batsfjord
# Processing Record 5 of Set 15 | berdigestyakh
# Processing Record 6 of Set 15 | sangueya
# Processing Record 7 of Set 15 | palu
# Processing Record 8 of Set 15 | necochea
# Processing Record 9 of Set 15 | puerto colombia
# Processing Record 10 of Set 15 | wagar
# Processing Record 11 of Set 15 | butterworth
# Processing Record 12 of Set 15 | jibuti
# Processing Record 13 of Set 15 | sao domingos
# Processing Record 14 of Set 15 | atikokan
# Processing Record 15 of Set 15 | sujiatun
# Processing Record 16 of Set 15 | svetlaya
# Processing Record 17 of Set 15 | sinjai
# Processing Record 18 of Set 15 | wa
# City not found. Skipping...
# Processing Record 19 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 15 | goma
# Processing Record 21 of Set 15 | yermolayevo
# Processing Record 22 of Set 15 | port blair
# Processing Record 23 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 15 | bilibino
# Processing Record 25 of Set 15 | kumbo
# Processing Record 26 of Set 15 | praia da vitoria
# Processing Record 27 of Set 15 | okhotsk
# Processing Record 28 of Set 15 | baie-comeau
# Processing Record 29 of Set 15 | mount hagen
# Processing Record 30 of Set 15 | juneau
# Processing Record 31 of Set 15 | oktyabrskiy
# Processing Record 32 of Set 15 | narasannapeta
# Processing Record 33 of Set 15 | luangwa
# Processing Record 34 of Set 15 | melsungen
# Processing Record 35 of Set 15 | korla
# Processing Record 36 of Set 15 | surt
# Processing Record 37 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 15 | camacari
# Processing Record 39 of Set 15 | yaviza
# Processing Record 40 of Set 15 | kajaani
# Processing Record 41 of Set 15 | pangody
# Processing Record 42 of Set 15 | coahuayana
# Processing Record 43 of Set 15 | kahramanmaras
# Processing Record 44 of Set 15 | lockhart
# Processing Record 45 of Set 15 | harper
# Processing Record 46 of Set 15 | porosozero
# Processing Record 47 of Set 15 | gilbues
# Processing Record 48 of Set 15 | nhulunbuy
# Processing Record 49 of Set 15 | svirstroy
# Processing Record 50 of Set 15 | halifax
# Processing Record 1 of Set 16 | bridlington
# Processing Record 2 of Set 16 | saint anthony
# Processing Record 3 of Set 16 | fare
# Processing Record 4 of Set 16 | bella vista
# Processing Record 5 of Set 16 | mizdah
# Processing Record 6 of Set 16 | taitung
# Processing Record 7 of Set 16 | daru
# Processing Record 8 of Set 16 | ca mau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0      Kapaa  22.0752 -159.3190              Clouds     74.19        91
# 1  Cape Town -33.9258   18.4232              Clouds     64.27        74
# 2  Saskylakh  71.9167  114.0833              Clouds      3.70        98
# 3     Shache  38.4167   77.2406              Clouds     51.85        54
# 4     Mackay -21.1500  149.2000               Clear     66.69        94
# 5    Rikitea -23.1203 -134.9692                Rain     77.74        68
# 6      Werda -25.2667   23.2833              Clouds     78.69        35
# 7    Kavieng  -2.5744  150.7967                Rain     81.68        77
# 8     Shingu  33.7333  135.9833                Rain     48.36        88
# 9  Tecoanapa  16.5167  -98.7500              Clouds     81.36        51
#
#    Cloudiness  Wind Speed Country
# 0          75       12.66      US
# 1          28        5.01      ZA
# 2         100        5.39      RU
# 3          42       10.98      CN
# 4           9        5.75      AU
# 5          60       16.98      PF
# 6          39        5.19      BW
# 7         100       13.94      PG
# 8         100        6.26      JP
# 9          44       11.12      MX

# %%
# Reorder the DataFrame columns
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kapaa      US  22.0752 -159.3190     74.19        91          75
# 1      Cape Town      ZA -33.9258   18.4232     64.27        74          28
# 2      Saskylakh      RU  71.9167  114.0833      3.70        98         100
# 3         Shache      CN  38.4167   77.2406     51.85        54          42
# 4         Mackay      AU -21.1500  149.2000     66.69        94           9
# ..           ...     ...      ...       ...       ...       ...         ...
# 694  Bella Vista      US  36.4295  -94.2316     40.98        82         100
# 695       Mizdah      LY  31.4451   12.9801     74.23        21           3
# 696      Taitung      TW  22.7583  121.1444     71.10        89          58
# 697         Daru      PG  -9.0763  143.2092     76.28        90          98
# 698       Ca Mau      VN   9.1769  105.1500     78.76        86          95
#
#      Wind Speed Current Description
# 0         12.66              Clouds
# 1          5.01              Clouds
# 2          5.39              Clouds
# 3         10.98              Clouds
# 4          5.75               Clear
# ..          ...                 ...
# 694       12.66              Clouds
# 695       21.39               Clear
# 696       21.92              Clouds
# 697        8.21                Rain
# 698        3.44              Clouds
#
# [699 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
